# %%
d = {
    "key":"value", 
    "key1":"value1", 
    "key2":"value2", 
     }

# %%
from box import ConfigBox

# %%
d2 = ConfigBox(
    d
)

# %%
d2
# Out:
# ConfigBox({'key': 'value', 'key1': 'value1', 'key2': 'value2'})

# %%
d2.keys()
# Out:
# dict_keys(['key', 'key1', 'key2'])
